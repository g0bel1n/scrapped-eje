# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,5)})

# %%
df = pd.read_csv('../src/data/vinted.csv').drop(['Unnamed: 0'], axis=1, inplace=False)

# %%
df
# Out:
#                     ÉTAT  NOMBRE DE VUES        EMPLACEMENT  \
# 0          TRÈS BON ÉTAT              47  BARCELONA, ESPAÑA
# 1          TRÈS BON ÉTAT             378  BARCELONA, ESPAÑA
# 2          TRÈS BON ÉTAT             168      LEIOA, ESPAÑA
# 3          TRÈS BON ÉTAT              29  BARCELONA, ESPAÑA
# 4          TRÈS BON ÉTAT              37  BARCELONA, ESPAÑA
# ..                   ...             ...                ...
# 96         TRÈS BON ÉTAT             787      PARIS, FRANCE
# 97         TRÈS BON ÉTAT             633      PARIS, FRANCE
# 98         TRÈS BON ÉTAT             369      PARIS, FRANCE
# 99              BON ÉTAT             141      PARIS, FRANCE
# 100  NEUF AVEC ÉTIQUETTE             128       LYON, FRANCE
#
#                 MARQUE         TAILLE                      AJOUTÉ  \
# 0         PULL & BEAR      S / 36 / 8  2022-04-02 14:25:07.149291
# 1    ZADIG & VOLTAIRE      S / 36 / 8  2022-04-04 14:25:07.149540
# 2             BERSHKA      S / 36 / 8  2022-04-04 14:25:07.149548
# 3             LACOSTE     L / 40 / 12  2022-03-30 14:25:07.149552
# 4             LACOSTE    XL / 42 / 14  2022-03-30 14:25:07.149570
# ..                 ...            ...                         ...
# 96   AMERICAN VINTAGE      S / 36 / 8  2022-04-04 14:25:07.149916
# 97    & OTHER STORIES     L / 40 / 12  2022-04-04 14:25:07.149919
# 98    & OTHER STORIES      S / 36 / 8  2022-04-04 14:25:07.149921
# 99             SANDRO   TAILLE UNIQUE  2022-04-04 14:25:07.149923
# 100              LILI   TAILLE UNIQUE  2022-04-04 14:25:07.149925
#
#                                                  nom   prix  \
# 0                     Jersey/Vestido del Pull & Bear    5.0
# 1                     Pull cachmere Zadig & Voltaire  110.0
# 2    Jersey con bufanda Pull avec echarpe multicolor    9.0
# 3                  Pull Lacoste Yellow Logo Bordee L   35.0
# 4          Pull Lacoste Rouge Burdeos Logo Bordee XL   35.0
# ..                                               ...    ...
# 96                             Pull American Vintage   17.0
# 97                               Pull &other stories   12.0
# 98                        Sweat pulll &other stories   15.0
# 99                                       Pull Sandro   10.0
# 100                                Pull lili et lola   28.0
#
#                                            description
# 0    Jersey blanco (puede usarse como vestido) usad...
# 1    en taille S, convient à un 36/38, porté deux f...
# 2               Jersey oversize multicolor con bufanda
# 3    Expédition le jour même 📦 uniquement par DHL, ...
# 4    Expédition le jour même 📦 uniquement par DHL, ...
# ..                                                 ...
# 96   Pull de la marque American vintage en trés bon...
# 97   En très bon état couleur noir/bleu metalisé\nL...
# 98          Taille S en trés bon état \nMotif broderie
# 99   Pull chaud de la marque Sandro taille 2\nIl a ...
# 100                                  Neuf jamais porté
#
# [101 rows x 9 columns]

# %%
df.plot(y='prix', x='AJOUTÉ')
# Out:
# <AxesSubplot:xlabel='AJOUTÉ'>
