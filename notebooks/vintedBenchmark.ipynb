# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,5)})

# %%
df = pd.read_csv('../src/data/vinted250.csv').drop(['Unnamed: 0'], axis=1, inplace=False)

# %%
df
# Out:
#                     ÉTAT  NOMBRE DE VUES             EMPLACEMENT  \
# 0    NEUF SANS ÉTIQUETTE              12         ALLAUCH, FRANCE
# 1    NEUF AVEC ÉTIQUETTE               5          NANTES, FRANCE
# 2               BON ÉTAT              14      SECONDIGNY, FRANCE
# 3          TRÈS BON ÉTAT             316           NÉZEL, FRANCE
# 4          TRÈS BON ÉTAT              22          ÉPINAL, FRANCE
# ..                   ...             ...                     ...
# 246        TRÈS BON ÉTAT             321       BELGIQUE / BELGIË
# 247        TRÈS BON ÉTAT             150                  FRANCE
# 248             BON ÉTAT             108           PARIS, FRANCE
# 249  NEUF SANS ÉTIQUETTE             107        BORDEAUX, FRANCE
# 250        TRÈS BON ÉTAT              55  BONNAC-LA-CÔTE, FRANCE
#
#                    MARQUE                 TAILLE                      AJOUTÉ  \
# 0                     NaN             S / 36 / 8  2022-04-04 12:02:45.109305
# 1             SANTA CRUZ                       M  2022-04-04 15:02:45.113667
# 2    MES PETITS CAILLOUX   18-24 MOIS / 86-92 CM  2022-04-04 10:02:45.113684
# 3                   NIKE                       S  2022-04-02 15:02:45.113692
# 4                 DISNEY           4XL / 48 / 20  2022-04-04 13:02:45.113697
# ..                    ...                    ...                         ...
# 246              LACOSTE                       L  2022-03-26 15:02:45.114822
# 247                   NaN          TAILLE UNIQUE  2022-03-25 15:02:45.114827
# 248               SÉZANE              S / 36 / 8  2022-04-04 15:02:45.114831
# 249             MONOPRIX             M / 38 / 10  2022-03-22 15:02:45.114836
# 250           LA REDOUTE          XXXL / 46 / 18  2022-04-04 15:02:45.114841
#
#                                                    nom   prix  \
# 0                                        Pull dentelle   8.00
# 1                         Pull Santa Cruz speed Wheels  60.00
# 2                                  Pull avec des motif   5.00
# 3                                       Pull Nike noir   6.99
# 4                                          Pull Disney  20.00
# ..                                                 ...    ...
# 246                               Sweat Pull Lacoste 🐊  39.90
# 247  Très jolie pull très fin bleu made Italy avec ...  17.90
# 248                              Pull sezane rose pale  30.00
# 249                             Pull monoprix taille M  45.00
# 250                                         Pull col v   4.00
#
#                                            description
# 0                                          jamais pote
# 1    Salut \nJe met en vente ce pull Santa Cruz \nt...
# 2                                               Porter
# 3    Article jamais utilisé et en parfait état #pul...
# 4                                          Pull Disney
# ..                                                 ...
# 246  Prix négociable avec les abonnés à mon compte ...
# 247  Très jolie pull fin bleu avec liseré argenté a...
# 248  pull sezane en mohair rose pâle\n\ndentelle bl...
# 249  porté une fois excellent état comme neuf.\nbel...
# 250   Pull col v la redoute ton de menthe,taille 46/48
#
# [251 rows x 9 columns]

# %%
df
# Out:
# <AxesSubplot:xlabel='AJOUTÉ'>
